# %%
import pandas as pd
file_path = r'C:\Users\hp\Desktop\مبادره مشاريع\data set\data pro2\house_data.csv'

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
print('This dataset includes', df.shape[0], 'rows and', df.shape[1], 'columns.')
# Out:
# This dataset includes 21613 rows and 21 columns.

# %% [markdown]
# # II. Exploratory Data Analysis (EDA)

# %%
#Discover type of each column:

df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      15
# float64     5
# object      1
# Name: count, dtype: int64

# %%
df.dtypes.value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# # Statistical description of dataset

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %% [markdown]
# Histograms of continous variables:

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# the distribution of price:
plt.figure(figsize = (10,7))
sns.distplot(df['price'],hist = True, label = 'Price')
plt.xlabel('price', fontsize = 16)
plt.ylabel('Density', fontsize = 16)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7768\385322483.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'],hist = True, label = 'Price')

# %% [markdown]
# Comment: Based on the figure above, we see that
#
# Almost house prices are distributed from 0 to 1 million dollars.
# Prices around 0.5 millions dollars appear most frequently.
# There exist some outliers values that we can skip in order to present their influence to our ML model.

# %% [markdown]
# # III. Preprocessing data

# %% [markdown]
# Based on the distribution of price, there is only some values which are larger than 2.5 million. Therefore we can consider t=2.5*10^6
#  as a threshold for filtering the outliers. All the house whose prices larger than
#  will be dropped from the dataset.

# %%
t = 2.5*10**6
df_new = df[df['price']<= t]

# %%
df_new.shape
# Out:
# (21516, 21)

# %%
df.shape[0] - df_new.shape[0]
# Out:
# 97

# %%
plt.figure(figsize=(10,7))
sns.distplot(df_new['price'])
plt.xlabel('price', fontsize = 16)
plt.ylabel('Density', fontsize = 16)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7768\2684832133.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_new['price'])

# %%
df_new = df_new.drop(['id','date', 'zipcode'], axis = 1)

# %%
df_new.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15
# 0  47.5112 -122.257           1340        5650
# 1  47.7210 -122.319           1690        7639
# 2  47.7379 -122.233           2720        8062
# 3  47.5208 -122.393           1360        5000
# 4  47.6168 -122.045           1800        7503

# %%
plt.figure(figsize = (8,8))
sns.clustermap(df_new.corr())

# %% [markdown]
# # Split randomly the dataset into training and test sets, where the ratio of test set is 20%.

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(df_new, test_size = 0.2, random_state = 0)

# %%
print('Train size: ', train_set.shape[0], 'Test size: ', test_set.shape[0])
# Out:
# Train size:  17212 Test size:  4304

# %%
plt.figure()
df_new.plot(kind = 'scatter', x = 'long', y = 'lat', alpha = 0.8, c = 'price',cmap=plt.get_cmap('jet'), figsize = (12,8))
plt.legend()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7768\1134352750.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Normalize data

# %%
X_train = train_set.drop('price', axis = 1)
y_train = train_set['price']
X_test = test_set.drop('price', axis = 1)
y_test = test_set['price']

# %%
from sklearn.preprocessing import StandardScaler
     
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (17212, 17) (4304, 17)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %% [markdown]
# Linear Regresison model

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lin = lin_reg.predict(X_test)
y_test1 = np.array(y_test)

# %%
mse_lin = mean_squared_error(y_test,y_pred_lin)
rmse_lin = np.sqrt(mse_lin)
print('RMSE of Linear Regression is: ', round(rmse_lin,1))
# Out:
# RMSE of Linear Regression is:  167347.9

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 28005329517.491642
# R-squared: 0.7135249772852972

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Define the model with specific parameters
lin_reg = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1)

# Fit the model to the training data
lin_reg.fit(X_train, y_train)

# Make predictions on the test data
y_pred = lin_reg.predict(X_test)

# Compute and print the Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 28005329517.491642

# %%
y_pred_final = lin_reg.predict(X_test)
mse_final = mean_squared_error(y_test1, y_pred_final)
rmse_final = np.sqrt(mse_final)
print('RMSE of final model is: ', round(rmse_final,1))
# Out:
# RMSE of final model is:  167347.9

# %%
some_values = X_test[:100]
y_pred_some_values = lin_reg.predict(some_values)
y_true_some_values = y_test1[:100]

plt.figure(figsize = (10,6))
plt.plot(y_true_some_values, 'b', lw = 2, label = 'true values')
plt.plot(y_pred_some_values, 'r', lw = 2, label = 'predicted values')
plt.ylabel('price', fontsize = 16)
plt.legend()
plt.show()
